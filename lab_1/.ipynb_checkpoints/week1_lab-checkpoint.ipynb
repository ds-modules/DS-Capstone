# %% [markdown]
# ```
# BEGIN ASSIGNMENT
# requirements: requirements.txt
# overwrite_requirements: true
# init_cell: false
# export_cell:
#     pdf: false
# solutions_pdf: true
# generate:
#     seed: 42
#     show_results: true
# files:
#     - cereal.csv
#     - ratings.csv
# instructions: 'To submit this assignment, please upload both the IPYNB file for this notebook *and* the PDF generated by the cell below to Gradescope.'
# ```

# %% [markdown]
# # Lab 1 - Programming in `pandas`: Part 1

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Welcome to lab 1!
# In this lab, you will first download a dataset from an external source, then analyize it using basic `pandas` functions.
#
# There are many online sources to find datasets. One of the most well known sites to find datasets is [Kaggle](https://www.kaggle.com), which hosts data science competitions and challenges.
# In fact, the dataset used in this lab will be from Kaggle. Another site where you can search for datasets is Google's own [Dataset Search Engine](https://datasetsearch.research.google.com/)

# %% [markdown]
# ## Cereals

# %% [markdown]
# Your best friend Shashank has been noticing that his normal breakfast cereal contains too much sugar per serving for his liking.
# Shashank has recently started his journey on healthy eating and excercising.
# He would like to know more about which cereal is the best in terms of nutritional value.
# Not knowing much about data anaysis, Shashank turns to you for help on finding the best cereal.
#
# A dataset about cereal and their nutritional value can be found here: https://www.kaggle.com/crawford/80-cereals
#
# You can get an overall understanding of what this dataset records by reading the description of the data.

# %% [markdown]
# ###  Question 1 - Getting your Data
# After reading the dataset description, complete the following steps:
#
# 1. Download the dataset as a `csv` from Kaggle. You will need to make a Kaggle account to download the dataset.
# 2. Unzip the data into your current directory, if the file downloads as a `zip`
# 3. Rename the `csv` file to be `cereal.csv` and upload it to your current directory

# %% [markdown]
# Now, we can read in the `csv` as a dataframe using `pandas`.
# Assign the filepath to `dataset_filepath` as a string and load the cereal dataframe into `cereal`.
#
# Since you should have uploaded the file to the same folder where this notebook is located, `dataset_filepath` should just be the name of the `csv`.
#
# ```
# BEGIN QUESTION
# name: q1
# ```

# %%
""" # BEGIN PROMPT
# File name 
dataset_filepath = ...

# Read in the file using pandas
cereal = ...
cereal.head()
# END PROMPT
"""
# BEGIN SOLUTION NO PROMPT
## SOLUTION ##
# File name 
dataset_filepath = 'cereal.csv'

# Read in the file using pandas
cereal = pd.read_csv(dataset_filepath)
cereal.head()
# END SOLUTION
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
## Test ##
assert len(cereal.columns) == 16

# %%
## Test ##
assert type(cereal) == type(pd.DataFrame())

# %% [markdown]
# ### Question 2 - Understanding your Data

# %% [markdown]
# **Question 2.1:** How extensive will your research be using this dataset?
# To answer this question you need to find out how many different types of cereal we have in this dataset.
# Assign `num_types` to the total number of cereals recorded.
#
#
# ```
# BEGIN QUESTION
# name: q2_1
# ```

# %%
""" # BEGIN PROMPT

num_types = ...
num_types

# END PROMPT """

# BEGIN SOLUTION NO PROMPT

## SOLUTION ##
num_types = cereal.shape[0]
num_types

# END SOLUTION
# Out:
# 77

# %%
## Test ##

assert num_types == 77

# %% [markdown]
# **Question 2.2:** How many columns does our dataset have? Assign `num_columns` to the number of columns in our dataset.
#
# ```
# BEGIN QUESTION
# name: q2_2
# ```

# %%
""" # BEGIN PROMPT

num_columns = ...
num_columns

# END PROMPT """

# BEGIN SOLUTION NO PROMPT

## SOLUTION ##
num_columns = cereal.shape[1]
num_columns

# END SOLUTION
# Out:
# 16

# %%
## Test ##

assert num_columns == 16

# %% [markdown]
# **Question 2.3:** To get a general understanding of the data, you would like to look at the first 20 cereals listed in this dataset. Assign
# `first_twenty` to a dataframe that contains the first 20 rows of the cereal dataset.
#
# ```
# BEGIN QUESTION
# name: q2_3
# ```

# %%
""" # BEGIN PROMPT
first_twenty = ...
# END PROMPT """

# BEGIN SOLUTION NO PROMPT 

## SOLUTION ##
first_twenty = cereal.head(20)
first_twenty

# END SOLUTION
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# 11                   Cheerios   G    C       110        6    2     290    2.0
# 12      Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 13                   Clusters   G    C       110        3    2     140    2.0
# 14                Cocoa Puffs   G    C       110        1    1     180    0.0
# 15                  Corn Chex   R    C       110        2    0     280    0.0
# 16                Corn Flakes   K    C       100        2    0     290    1.0
# 17                  Corn Pops   K    C       110        1    0      90    1.0
# 18              Count Chocula   G    C       110        1    1     180    0.0
# 19         Cracklin' Oat Bran   K    C       110        3    3     140    4.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 1     8.0       8     135         0      3    1.00  1.00  33.983679
# 2     7.0       5     320        25      3    1.00  0.33  59.425505
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 4    14.0       8      -1        25      3    1.00  0.75  34.384843
# 5    10.5      10      70        25      1    1.00  0.75  29.509541
# 6    11.0      14      30        25      2    1.00  1.00  33.174094
# 7    18.0       8     100        25      3    1.33  0.75  37.038562
# 8    15.0       6     125        25      1    1.00  0.67  49.120253
# 9    13.0       5     190        25      3    1.00  0.67  53.313813
# 10   12.0      12      35        25      2    1.00  0.75  18.042851
# 11   17.0       1     105        25      1    1.00  1.25  50.764999
# 12   13.0       9      45        25      2    1.00  0.75  19.823573
# 13   13.0       7     105        25      3    1.00  0.50  40.400208
# 14   12.0      13      55        25      2    1.00  1.00  22.736446
# 15   22.0       3      25        25      1    1.00  1.00  41.445019
# 16   21.0       2      35        25      1    1.00  1.00  45.863324
# 17   13.0      12      20        25      2    1.00  1.00  35.782791
# 18   12.0      13      65        25      2    1.00  1.00  22.396513
# 19   10.0       7     160        25      3    1.00  0.50  40.448772

# %%
## Test ##
assert len(first_twenty.columns) == 16

# %%
## Test ##
assert len(first_twenty.index) == 20

# %%
## Test ##
assert first_twenty.iloc[10,10] == 35

# %%
## Test ##
assert first_twenty.iloc[1,4] == 3

# %%
## Test ##
assert type(first_twenty) == type(pd.DataFrame())

# %% [markdown]
# ### Question 3 - Indexing your Data

# %% [markdown]
# **Question 3.1:** Shashank's current favorite cereal is `Fruity Pebbles`. He would like to know the amount of calories and sugar per serving for this cereal.
#
# Assign `pebbles` to a dataframe containing only the amount of calories and sugars per serving of `Fruity Pebbles`.
#
# ```
# BEGIN QUESTION
# name: q3_1
# ```

# %%
""" # BEGIN PROMPT

pebbles = ...
pebbles

# END PROMPT """

# BEGIN SOLUTION NO PROMPT

## SOLUTION ##
pebbles = cereal[cereal["name"] == 'Fruity Pebbles'].loc[:, ['calories', 'sugars']]
pebbles

# END SOLUTION
# Out:
#     calories  sugars
# 29       110      12

# %%
## Test ##
assert len(pebbles.columns) == 2

# %%
## Test ##
assert len(pebbles.index) == 1

# %%
## Test ##
assert pebbles["sugars"].iloc[0] == 12

# %%
## Test ##
assert pebbles["calories"].iloc[0] == 110

# %%
## Test ##
assert type(pebbles) == type(pd.DataFrame())

# %% [markdown]
# **Question 3.2:** What cereal(s) has the most amount of protein (and consequently is the best for Shashank's gains)? Assign `most_protein` to the name of the cereal with the most protein. If there are multiple cereals with the most protein, you can assign `most_protein` to any of the cereals.
#
# _Hint:_ Remeber, if you are doing `series_name[5]`, you are extracting the value with index 5, and not the 5th element.
#
# ```
# BEGIN QUESTION
# name: q3_2
# ```

# %%
""" ##BEGIN PROMPT
most_protein = ...
most_protein

## END PROMPT """

# BEGIN SOLUTION NO PROMPT

## Solution ##
most_protein = cereal.sort_values(by = "protein", ascending = False)["name"].values[0]
most_protein

# END SOLUTION
# Out:
# 'Cheerios'

# %%
## Test ##
assert (most_protein == 'Cheerios' or most_protein == 'Special K')

# %% [markdown]
# **Question 3.3:** Shashank says that he is also interested in maximizing fiber intake for breakfast.
# He asks you to find all the cereals with greater than or equal to 4 grams of protein and more than 3 grams of fiber.
# Assign `qualified_cereals` to all the cereals that have greater than or equal to 4 grams of protein and more than 3 grams of fiber.
#
# ```
# BEGIN QUESTION
# name: q3_3
# ```

# %%
""" ## BEGIN PROMPT

qualified_cereals = ...
qualified_cereals

## END PROMPT """

# BEGIN SOLUTION NO PROMPT
## SOLUTION ##
qualified_cereals = cereal.loc[(cereal['protein'] >= 4) & (cereal['fiber'] > 3)]
qualified_cereals
# END SOLUTION
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912

# %%
## Test ##
assert len(qualified_cereals.index) == 3

# %%
## Test ##
assert np.count_nonzero(qualified_cereals['protein'] >= 4) == 3

# %%
## Test ##
assert np.count_nonzero(qualified_cereals['fiber'] > 3) == 3

# %%
## Test ##
assert type(qualified_cereals) == type(pd.DataFrame())

# %% [markdown]
# **Question 3.4:** Suppose we are only interested in the name, protein, fiber, calories, vitamins, and sugar values of all the cereals.
# Use `.loc` to return a dataframe with all the cereals containing only our columns of interest in the order presented above. Assign this dataframe to the variable `cereal_loc`.
#
# ```
# BEGIN QUESTION
# name: q3_4
# ```

# %%
""" ## BEGIN PROMPT
cereal_loc = ...
cereal_loc
## END PROMPT """

# BEGIN SOLUTION NO PROMPT
# SOLUTION
cereal_loc = cereal.loc[:, ['name', 'protein', 'fiber', 'calories', 'vitamins', 'sugars']]
cereal_loc

# END SOLUTION
# Out:
#                                       name  protein  fiber  calories  \
# 0                                100% Bran        4   10.0        70
# 1                        100% Natural Bran        3    2.0       120
# 2                                 All-Bran        4    9.0        70
# 3                All-Bran with Extra Fiber        4   14.0        50
# 4                           Almond Delight        2    1.0       110
# 5                  Apple Cinnamon Cheerios        2    1.5       110
# 6                              Apple Jacks        2    1.0       110
# 7                                  Basic 4        3    2.0       130
# 8                                Bran Chex        2    4.0        90
# 9                              Bran Flakes        3    5.0        90
# 10                            Cap'n'Crunch        1    0.0       120
# 11                                Cheerios        6    2.0       110
# 12                   Cinnamon Toast Crunch        1    0.0       120
# 13                                Clusters        3    2.0       110
# 14                             Cocoa Puffs        1    0.0       110
# 15                               Corn Chex        2    0.0       110
# 16                             Corn Flakes        2    1.0       100
# 17                               Corn Pops        1    1.0       110
# 18                           Count Chocula        1    0.0       110
# 19                      Cracklin' Oat Bran        3    4.0       110
# 20                  Cream of Wheat (Quick)        3    1.0       100
# 21                                 Crispix        2    1.0       110
# 22                  Crispy Wheat & Raisins        2    2.0       100
# 23                             Double Chex        2    1.0       100
# 24                             Froot Loops        2    1.0       110
# 25                          Frosted Flakes        1    1.0       110
# 26                     Frosted Mini-Wheats        3    3.0       100
# 27  Fruit & Fibre Dates; Walnuts; and Oats        3    5.0       120
# 28                           Fruitful Bran        3    5.0       120
# 29                          Fruity Pebbles        1    0.0       110
# ..                                     ...      ...    ...       ...
# 47                    Multi-Grain Cheerios        2    2.0       100
# 48                        Nut&Honey Crunch        2    0.0       120
# 49               Nutri-Grain Almond-Raisin        3    3.0       140
# 50                       Nutri-grain Wheat        3    3.0        90
# 51                    Oatmeal Raisin Crisp        3    1.5       130
# 52                   Post Nat. Raisin Bran        3    6.0       120
# 53                              Product 19        3    1.0       100
# 54                             Puffed Rice        1    0.0        50
# 55                            Puffed Wheat        2    1.0        50
# 56                      Quaker Oat Squares        4    2.0       100
# 57                          Quaker Oatmeal        5    2.7       100
# 58                             Raisin Bran        3    5.0       120
# 59                         Raisin Nut Bran        3    2.5       100
# 60                          Raisin Squares        2    2.0        90
# 61                               Rice Chex        1    0.0       110
# 62                           Rice Krispies        2    0.0       110
# 63                          Shredded Wheat        2    3.0        80
# 64                  Shredded Wheat 'n'Bran        3    4.0        90
# 65               Shredded Wheat spoon size        3    3.0        90
# 66                                  Smacks        2    1.0       110
# 67                               Special K        6    1.0       110
# 68                 Strawberry Fruit Wheats        2    3.0        90
# 69                       Total Corn Flakes        2    0.0       110
# 70                       Total Raisin Bran        3    4.0       140
# 71                       Total Whole Grain        3    3.0       100
# 72                                 Triples        2    0.0       110
# 73                                    Trix        1    0.0       110
# 74                              Wheat Chex        3    3.0       100
# 75                                Wheaties        3    3.0       100
# 76                     Wheaties Honey Gold        2    1.0       110
#
#     vitamins  sugars
# 0         25       6
# 1          0       8
# 2         25       5
# 3         25       0
# 4         25       8
# 5         25      10
# 6         25      14
# 7         25       8
# 8         25       6
# 9         25       5
# 10        25      12
# 11        25       1
# 12        25       9
# 13        25       7
# 14        25      13
# 15        25       3
# 16        25       2
# 17        25      12
# 18        25      13
# 19        25       7
# 20         0       0
# 21        25       3
# 22        25      10
# 23        25       5
# 24        25      13
# 25        25      11
# 26        25       7
# 27        25      10
# 28        25      12
# 29        25      12
# ..       ...     ...
# 47        25       6
# 48        25       9
# 49        25       7
# 50        25       2
# 51        25      10
# 52        25      14
# 53       100       3
# 54         0       0
# 55         0       0
# 56        25       6
# 57         0      -1
# 58        25      12
# 59        25       8
# 60        25       6
# 61        25       2
# 62        25       3
# 63         0       0
# 64         0       0
# 65         0       0
# 66        25      15
# 67        25       3
# 68        25       5
# 69       100       3
# 70       100      14
# 71       100       3
# 72        25       3
# 73        25      12
# 74        25       3
# 75        25       3
# 76        25       8
#
# [77 rows x 6 columns]

# %%
## Test ##
assert len(cereal_loc.index) == 77

# %%
## Test ##
assert len(cereal_loc.columns) == 6

# %%
## Test ##
assert cereal_loc.columns[0] == 'name'

# %%
## Test ##
assert cereal_loc.columns[1] == 'protein'

# %%
## Test ##
assert cereal_loc.columns[2] == 'fiber'

# %%
## Test ##
assert cereal_loc.columns[3] == 'calories'

# %%
## Test ##
assert cereal_loc.columns[4] == 'vitamins'

# %%
## Test ##
assert cereal_loc.columns[5] == 'sugars'

# %%
## Test ##
assert type(cereal_loc) == type(pd.DataFrame())

# %% [markdown]
# **Question 3.5:** After seeing `cereal_loc`, Shashank tells you that he is not interested in the vitamin content of different cereals. Use the  `.drop` funftion to drop all the columns that we do not want.
# Assign this dataframe to the variable `cereal_drop`.
#
# *Hint:* Make sure you are dropping labels along the column axis.
#
# ```
# BEGIN QUESTION
# name: q3_5
# ```

# %%
""" ## BEGIN PROMPT
cereal_drop = ...
cereal_drop

## END PROMPT """

# BEGIN SOLUTION NO PROMPT
## SOLUTION ##
cereal_drop = cereal_loc.drop(labels = ['vitamins'], axis = 1)
cereal_drop
# END SOLUTION
# Out:
#                                       name  protein  fiber  calories  sugars
# 0                                100% Bran        4   10.0        70       6
# 1                        100% Natural Bran        3    2.0       120       8
# 2                                 All-Bran        4    9.0        70       5
# 3                All-Bran with Extra Fiber        4   14.0        50       0
# 4                           Almond Delight        2    1.0       110       8
# 5                  Apple Cinnamon Cheerios        2    1.5       110      10
# 6                              Apple Jacks        2    1.0       110      14
# 7                                  Basic 4        3    2.0       130       8
# 8                                Bran Chex        2    4.0        90       6
# 9                              Bran Flakes        3    5.0        90       5
# 10                            Cap'n'Crunch        1    0.0       120      12
# 11                                Cheerios        6    2.0       110       1
# 12                   Cinnamon Toast Crunch        1    0.0       120       9
# 13                                Clusters        3    2.0       110       7
# 14                             Cocoa Puffs        1    0.0       110      13
# 15                               Corn Chex        2    0.0       110       3
# 16                             Corn Flakes        2    1.0       100       2
# 17                               Corn Pops        1    1.0       110      12
# 18                           Count Chocula        1    0.0       110      13
# 19                      Cracklin' Oat Bran        3    4.0       110       7
# 20                  Cream of Wheat (Quick)        3    1.0       100       0
# 21                                 Crispix        2    1.0       110       3
# 22                  Crispy Wheat & Raisins        2    2.0       100      10
# 23                             Double Chex        2    1.0       100       5
# 24                             Froot Loops        2    1.0       110      13
# 25                          Frosted Flakes        1    1.0       110      11
# 26                     Frosted Mini-Wheats        3    3.0       100       7
# 27  Fruit & Fibre Dates; Walnuts; and Oats        3    5.0       120      10
# 28                           Fruitful Bran        3    5.0       120      12
# 29                          Fruity Pebbles        1    0.0       110      12
# ..                                     ...      ...    ...       ...     ...
# 47                    Multi-Grain Cheerios        2    2.0       100       6
# 48                        Nut&Honey Crunch        2    0.0       120       9
# 49               Nutri-Grain Almond-Raisin        3    3.0       140       7
# 50                       Nutri-grain Wheat        3    3.0        90       2
# 51                    Oatmeal Raisin Crisp        3    1.5       130      10
# 52                   Post Nat. Raisin Bran        3    6.0       120      14
# 53                              Product 19        3    1.0       100       3
# 54                             Puffed Rice        1    0.0        50       0
# 55                            Puffed Wheat        2    1.0        50       0
# 56                      Quaker Oat Squares        4    2.0       100       6
# 57                          Quaker Oatmeal        5    2.7       100      -1
# 58                             Raisin Bran        3    5.0       120      12
# 59                         Raisin Nut Bran        3    2.5       100       8
# 60                          Raisin Squares        2    2.0        90       6
# 61                               Rice Chex        1    0.0       110       2
# 62                           Rice Krispies        2    0.0       110       3
# 63                          Shredded Wheat        2    3.0        80       0
# 64                  Shredded Wheat 'n'Bran        3    4.0        90       0
# 65               Shredded Wheat spoon size        3    3.0        90       0
# 66                                  Smacks        2    1.0       110      15
# 67                               Special K        6    1.0       110       3
# 68                 Strawberry Fruit Wheats        2    3.0        90       5
# 69                       Total Corn Flakes        2    0.0       110       3
# 70                       Total Raisin Bran        3    4.0       140      14
# 71                       Total Whole Grain        3    3.0       100       3
# 72                                 Triples        2    0.0       110       3
# 73                                    Trix        1    0.0       110      12
# 74                              Wheat Chex        3    3.0       100       3
# 75                                Wheaties        3    3.0       100       3
# 76                     Wheaties Honey Gold        2    1.0       110       8
#
# [77 rows x 5 columns]

# %%
## Test ##
assert 'vitamins' not in cereal_drop.columns

# %%
## Test ##
assert len(cereal_drop.columns) == 5

# %%
## Test ##
assert len(cereal_drop.index) == 77

# %%
## Test ##
assert type(cereal_drop) == type(pd.DataFrame())

# %% [markdown]
# **Question 3.6:** Shashank brings back from Trader Joe's some Honey O's. He tells you the following nutritional information:
# - Name: Honey O's
# - Protein: 2 g
# - Fiber; 2 g
# - Calories: 110 kcal
# - Sugars: 9 g
#
# Add this new observation into your table `cereal_drop` from 3.5.
#
# *Hint:* replace the `...` after `.loc` with the index that you want the new row to be assigned to, and fill in the right hand side of the assignment as a list containing all nessecary nutritional information. The list should have 1 value for each column of the dataframe.
#
# ```
# BEGIN QUESTION
# name: q3_6
# ```

# %%
""" ## BEGIN PROMPT
cereal_drop.loc[...] = ...
cereal_drop

## END PROMPT """

# BEGIN SOLUTION NO PROMPT
cereal_drop.loc[77] = ["Honey O's", 2, 2, 110, 9]
cereal_drop
# END SOLUTION
# Out:
#                                       name  protein  fiber  calories  sugars
# 0                                100% Bran        4   10.0        70       6
# 1                        100% Natural Bran        3    2.0       120       8
# 2                                 All-Bran        4    9.0        70       5
# 3                All-Bran with Extra Fiber        4   14.0        50       0
# 4                           Almond Delight        2    1.0       110       8
# 5                  Apple Cinnamon Cheerios        2    1.5       110      10
# 6                              Apple Jacks        2    1.0       110      14
# 7                                  Basic 4        3    2.0       130       8
# 8                                Bran Chex        2    4.0        90       6
# 9                              Bran Flakes        3    5.0        90       5
# 10                            Cap'n'Crunch        1    0.0       120      12
# 11                                Cheerios        6    2.0       110       1
# 12                   Cinnamon Toast Crunch        1    0.0       120       9
# 13                                Clusters        3    2.0       110       7
# 14                             Cocoa Puffs        1    0.0       110      13
# 15                               Corn Chex        2    0.0       110       3
# 16                             Corn Flakes        2    1.0       100       2
# 17                               Corn Pops        1    1.0       110      12
# 18                           Count Chocula        1    0.0       110      13
# 19                      Cracklin' Oat Bran        3    4.0       110       7
# 20                  Cream of Wheat (Quick)        3    1.0       100       0
# 21                                 Crispix        2    1.0       110       3
# 22                  Crispy Wheat & Raisins        2    2.0       100      10
# 23                             Double Chex        2    1.0       100       5
# 24                             Froot Loops        2    1.0       110      13
# 25                          Frosted Flakes        1    1.0       110      11
# 26                     Frosted Mini-Wheats        3    3.0       100       7
# 27  Fruit & Fibre Dates; Walnuts; and Oats        3    5.0       120      10
# 28                           Fruitful Bran        3    5.0       120      12
# 29                          Fruity Pebbles        1    0.0       110      12
# ..                                     ...      ...    ...       ...     ...
# 48                        Nut&Honey Crunch        2    0.0       120       9
# 49               Nutri-Grain Almond-Raisin        3    3.0       140       7
# 50                       Nutri-grain Wheat        3    3.0        90       2
# 51                    Oatmeal Raisin Crisp        3    1.5       130      10
# 52                   Post Nat. Raisin Bran        3    6.0       120      14
# 53                              Product 19        3    1.0       100       3
# 54                             Puffed Rice        1    0.0        50       0
# 55                            Puffed Wheat        2    1.0        50       0
# 56                      Quaker Oat Squares        4    2.0       100       6
# 57                          Quaker Oatmeal        5    2.7       100      -1
# 58                             Raisin Bran        3    5.0       120      12
# 59                         Raisin Nut Bran        3    2.5       100       8
# 60                          Raisin Squares        2    2.0        90       6
# 61                               Rice Chex        1    0.0       110       2
# 62                           Rice Krispies        2    0.0       110       3
# 63                          Shredded Wheat        2    3.0        80       0
# 64                  Shredded Wheat 'n'Bran        3    4.0        90       0
# 65               Shredded Wheat spoon size        3    3.0        90       0
# 66                                  Smacks        2    1.0       110      15
# 67                               Special K        6    1.0       110       3
# 68                 Strawberry Fruit Wheats        2    3.0        90       5
# 69                       Total Corn Flakes        2    0.0       110       3
# 70                       Total Raisin Bran        3    4.0       140      14
# 71                       Total Whole Grain        3    3.0       100       3
# 72                                 Triples        2    0.0       110       3
# 73                                    Trix        1    0.0       110      12
# 74                              Wheat Chex        3    3.0       100       3
# 75                                Wheaties        3    3.0       100       3
# 76                     Wheaties Honey Gold        2    1.0       110       8
# 77                               Honey O's        2    2.0       110       9
#
# [78 rows x 5 columns]

# %%
## Test ##
assert len(cereal_drop.index) == 78

# %%
## Test ##
assert cereal_drop.iloc[77, 0] == "Honey O's"

# %%
## Test ##
assert cereal_drop.iloc[5, 0] == "Apple Cinnamon Cheerios"

# %%
## Test ##
assert type(cereal_drop) == type(pd.DataFrame())

# %% [markdown]
# ### Question 4

# %% [markdown]
# You realize that the `cups` column has different cups per serving, so that the nutritional information is not standardized across cereals.
# Since you normally eat 1 cup of cereal for breakfast, it would be better to see the nutritional values for each cereal per cup.
#
# Let's transform the data so that the dataframe reflects the nutritional values of each cereal per cup and store it in a new table called `serving`. `serving` should have all the columns of `cereal_drop`, but the `'calories', 'protein', 'fiber', 'sugars'` columns should reflect serving per 1 cup.
#
# *Hint 1:* For example, the serving size for cheerios is 1.25 and the caloric content is 110. We can divide calories by cups (110 / 1.25) to get calories per cup. Similarly, All-Bran with Extra Fiber has 50 calories for 0.5 (or 1/2) cups of serving. Could we divide calories by cups here as well?
#
# As a challenge, you can try using `df.div`. You can find the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.divide.html). Don't forget the `axis` argument.
#
# ```
# BEGIN QUESTION
# name: q4
# ```

# %%
""" ## BEGIN PROMPT
serving = ...
serving

## END PROMPT """

# BEGIN SOLUTION NO PROMPT
## SOLUTION ##
serving = cereal[['name', 'protein', 'fiber', 'calories', 'sugars', 'cups']]
serving['protein'] = serving['protein'] / serving['cups']
serving['fiber'] = serving['fiber'] / serving['cups']
serving['calories'] = serving['calories'] / serving['cups']
serving['sugars'] = serving['sugars'] / serving['cups']
serving = serving.drop('cups', axis = 1)
serving
# END SOLUTION
# Out:
#                                       name    protein      fiber    calories  \
# 0                                100% Bran  12.121212  30.303030  212.121212
# 1                        100% Natural Bran   3.000000   2.000000  120.000000
# 2                                 All-Bran  12.121212  27.272727  212.121212
# 3                All-Bran with Extra Fiber   8.000000  28.000000  100.000000
# 4                           Almond Delight   2.666667   1.333333  146.666667
# 5                  Apple Cinnamon Cheerios   2.666667   2.000000  146.666667
# 6                              Apple Jacks   2.000000   1.000000  110.000000
# 7                                  Basic 4   4.000000   2.666667  173.333333
# 8                                Bran Chex   2.985075   5.970149  134.328358
# 9                              Bran Flakes   4.477612   7.462687  134.328358
# 10                            Cap'n'Crunch   1.333333   0.000000  160.000000
# 11                                Cheerios   4.800000   1.600000   88.000000
# 12                   Cinnamon Toast Crunch   1.333333   0.000000  160.000000
# 13                                Clusters   6.000000   4.000000  220.000000
# 14                             Cocoa Puffs   1.000000   0.000000  110.000000
# 15                               Corn Chex   2.000000   0.000000  110.000000
# 16                             Corn Flakes   2.000000   1.000000  100.000000
# 17                               Corn Pops   1.000000   1.000000  110.000000
# 18                           Count Chocula   1.000000   0.000000  110.000000
# 19                      Cracklin' Oat Bran   6.000000   8.000000  220.000000
# 20                  Cream of Wheat (Quick)   3.000000   1.000000  100.000000
# 21                                 Crispix   2.000000   1.000000  110.000000
# 22                  Crispy Wheat & Raisins   2.666667   2.666667  133.333333
# 23                             Double Chex   2.666667   1.333333  133.333333
# 24                             Froot Loops   2.000000   1.000000  110.000000
# 25                          Frosted Flakes   1.333333   1.333333  146.666667
# 26                     Frosted Mini-Wheats   3.750000   3.750000  125.000000
# 27  Fruit & Fibre Dates; Walnuts; and Oats   4.477612   7.462687  179.104478
# 28                           Fruitful Bran   4.477612   7.462687  179.104478
# 29                          Fruity Pebbles   1.333333   0.000000  146.666667
# ..                                     ...        ...        ...         ...
# 47                    Multi-Grain Cheerios   2.000000   2.000000  100.000000
# 48                        Nut&Honey Crunch   2.985075   0.000000  179.104478
# 49               Nutri-Grain Almond-Raisin   4.477612   4.477612  208.955224
# 50                       Nutri-grain Wheat   3.000000   3.000000   90.000000
# 51                    Oatmeal Raisin Crisp   6.000000   3.000000  260.000000
# 52                   Post Nat. Raisin Bran   4.477612   8.955224  179.104478
# 53                              Product 19   3.000000   1.000000  100.000000
# 54                             Puffed Rice   1.000000   0.000000   50.000000
# 55                            Puffed Wheat   2.000000   1.000000   50.000000
# 56                      Quaker Oat Squares   8.000000   4.000000  200.000000
# 57                          Quaker Oatmeal   7.462687   4.029851  149.253731
# 58                             Raisin Bran   4.000000   6.666667  160.000000
# 59                         Raisin Nut Bran   6.000000   5.000000  200.000000
# 60                          Raisin Squares   4.000000   4.000000  180.000000
# 61                               Rice Chex   0.884956   0.000000   97.345133
# 62                           Rice Krispies   2.000000   0.000000  110.000000
# 63                          Shredded Wheat   2.000000   3.000000   80.000000
# 64                  Shredded Wheat 'n'Bran   4.477612   5.970149  134.328358
# 65               Shredded Wheat spoon size   4.477612   4.477612  134.328358
# 66                                  Smacks   2.666667   1.333333  146.666667
# 67                               Special K   6.000000   1.000000  110.000000
# 68                 Strawberry Fruit Wheats   2.000000   3.000000   90.000000
# 69                       Total Corn Flakes   2.000000   0.000000  110.000000
# 70                       Total Raisin Bran   3.000000   4.000000  140.000000
# 71                       Total Whole Grain   3.000000   3.000000  100.000000
# 72                                 Triples   2.666667   0.000000  146.666667
# 73                                    Trix   1.000000   0.000000  110.000000
# 74                              Wheat Chex   4.477612   4.477612  149.253731
# 75                                Wheaties   3.000000   3.000000  100.000000
# 76                     Wheaties Honey Gold   2.666667   1.333333  146.666667
#
#        sugars
# 0   18.181818
# 1    8.000000
# 2   15.151515
# 3    0.000000
# 4   10.666667
# 5   13.333333
# 6   14.000000
# 7   10.666667
# 8    8.955224
# 9    7.462687
# 10  16.000000
# 11   0.800000
# 12  12.000000
# 13  14.000000
# 14  13.000000
# 15   3.000000
# 16   2.000000
# 17  12.000000
# 18  13.000000
# 19  14.000000
# 20   0.000000
# 21   3.000000
# 22  13.333333
# 23   6.666667
# 24  13.000000
# 25  14.666667
# 26   8.750000
# 27  14.925373
# 28  17.910448
# 29  16.000000
# ..        ...
# 47   6.000000
# 48  13.432836
# 49  10.447761
# 50   2.000000
# 51  20.000000
# 52  20.895522
# 53   3.000000
# 54   0.000000
# 55   0.000000
# 56  12.000000
# 57  -1.492537
# 58  16.000000
# 59  16.000000
# 60  12.000000
# 61   1.769912
# 62   3.000000
# 63   0.000000
# 64   0.000000
# 65   0.000000
# 66  20.000000
# 67   3.000000
# 68   5.000000
# 69   3.000000
# 70  14.000000
# 71   3.000000
# 72   4.000000
# 73  12.000000
# 74   4.477612
# 75   3.000000
# 76  10.666667
#
# [77 rows x 5 columns]

# %%
## Test ##
assert len(serving.index) == 77

# %%
## Test ##
assert len(serving.columns) == 5

# %%
## Test ##
assert np.isclose(12.121212121, serving.iloc[0,1])

# %%
## Test ##
assert np.isclose(27.27272727, serving.iloc[2, 2])

# %%
## Test ##
assert type(serving) == type(pd.DataFrame())

# %% [markdown]
# ## Question 5

# %% [markdown]
# Shashank has tasted all of the different cereals and given them a rating on a scale of 1 (least) to 5(most). The information is stored in the file `ratings.csv`. Your task is to load the file and merge with with the cereal dataset such that each cereal
#
# ```
# BEGIN QUESTION
# name: q5
# ```

# %%
ratings = pd.read_csv("ratings.csv") # SOLUTION
cereal  = cereal.merge(ratings, on = "name") # SOLUTION
cereal
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# 14                             Cocoa Puffs   G    C       110        1    1
# 15                               Corn Chex   R    C       110        2    0
# 16                             Corn Flakes   K    C       100        2    0
# 17                               Corn Pops   K    C       110        1    0
# 18                           Count Chocula   G    C       110        1    1
# 19                      Cracklin' Oat Bran   K    C       110        3    3
# 20                  Cream of Wheat (Quick)   N    H       100        3    0
# 21                                 Crispix   K    C       110        2    0
# 22                  Crispy Wheat & Raisins   G    C       100        2    1
# 23                             Double Chex   R    C       100        2    0
# 24                             Froot Loops   K    C       110        2    1
# 25                          Frosted Flakes   K    C       110        1    0
# 26                     Frosted Mini-Wheats   K    C       100        3    0
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 28                           Fruitful Bran   K    C       120        3    0
# 29                          Fruity Pebbles   P    C       110        1    1
# ..                                     ...  ..  ...       ...      ...  ...
# 47                    Multi-Grain Cheerios   G    C       100        2    1
# 48                        Nut&Honey Crunch   K    C       120        2    1
# 49               Nutri-Grain Almond-Raisin   K    C       140        3    2
# 50                       Nutri-grain Wheat   K    C        90        3    0
# 51                    Oatmeal Raisin Crisp   G    C       130        3    2
# 52                   Post Nat. Raisin Bran   P    C       120        3    1
# 53                              Product 19   K    C       100        3    0
# 54                             Puffed Rice   Q    C        50        1    0
# 55                            Puffed Wheat   Q    C        50        2    0
# 56                      Quaker Oat Squares   Q    C       100        4    1
# 57                          Quaker Oatmeal   Q    H       100        5    2
# 58                             Raisin Bran   K    C       120        3    1
# 59                         Raisin Nut Bran   G    C       100        3    2
# 60                          Raisin Squares   K    C        90        2    0
# 61                               Rice Chex   R    C       110        1    0
# 62                           Rice Krispies   K    C       110        2    0
# 63                          Shredded Wheat   N    C        80        2    0
# 64                  Shredded Wheat 'n'Bran   N    C        90        3    0
# 65               Shredded Wheat spoon size   N    C        90        3    0
# 66                                  Smacks   K    C       110        2    1
# 67                               Special K   K    C       110        6    0
# 68                 Strawberry Fruit Wheats   N    C        90        2    0
# 69                       Total Corn Flakes   G    C       110        2    1
# 70                       Total Raisin Bran   G    C       140        3    1
# 71                       Total Whole Grain   G    C       100        3    1
# 72                                 Triples   G    C       110        2    1
# 73                                    Trix   G    C       110        1    1
# 74                              Wheat Chex   R    C       100        3    1
# 75                                Wheaties   G    C       100        3    1
# 76                     Wheaties Honey Gold   G    C       110        2    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0      130   10.0    5.0       6     280        25      3    1.00  0.33
# 1       15    2.0    8.0       8     135         0      3    1.00  1.00
# 2      260    9.0    7.0       5     320        25      3    1.00  0.33
# 3      140   14.0    8.0       0     330        25      3    1.00  0.50
# 4      200    1.0   14.0       8      -1        25      3    1.00  0.75
# 5      180    1.5   10.5      10      70        25      1    1.00  0.75
# 6      125    1.0   11.0      14      30        25      2    1.00  1.00
# 7      210    2.0   18.0       8     100        25      3    1.33  0.75
# 8      200    4.0   15.0       6     125        25      1    1.00  0.67
# 9      210    5.0   13.0       5     190        25      3    1.00  0.67
# 10     220    0.0   12.0      12      35        25      2    1.00  0.75
# 11     290    2.0   17.0       1     105        25      1    1.00  1.25
# 12     210    0.0   13.0       9      45        25      2    1.00  0.75
# 13     140    2.0   13.0       7     105        25      3    1.00  0.50
# 14     180    0.0   12.0      13      55        25      2    1.00  1.00
# 15     280    0.0   22.0       3      25        25      1    1.00  1.00
# 16     290    1.0   21.0       2      35        25      1    1.00  1.00
# 17      90    1.0   13.0      12      20        25      2    1.00  1.00
# 18     180    0.0   12.0      13      65        25      2    1.00  1.00
# 19     140    4.0   10.0       7     160        25      3    1.00  0.50
# 20      80    1.0   21.0       0      -1         0      2    1.00  1.00
# 21     220    1.0   21.0       3      30        25      3    1.00  1.00
# 22     140    2.0   11.0      10     120        25      3    1.00  0.75
# 23     190    1.0   18.0       5      80        25      3    1.00  0.75
# 24     125    1.0   11.0      13      30        25      2    1.00  1.00
# 25     200    1.0   14.0      11      25        25      1    1.00  0.75
# 26       0    3.0   14.0       7     100        25      2    1.00  0.80
# 27     160    5.0   12.0      10     200        25      3    1.25  0.67
# 28     240    5.0   14.0      12     190        25      3    1.33  0.67
# 29     135    0.0   13.0      12      25        25      2    1.00  0.75
# ..     ...    ...    ...     ...     ...       ...    ...     ...   ...
# 47     220    2.0   15.0       6      90        25      1    1.00  1.00
# 48     190    0.0   15.0       9      40        25      2    1.00  0.67
# 49     220    3.0   21.0       7     130        25      3    1.33  0.67
# 50     170    3.0   18.0       2      90        25      3    1.00  1.00
# 51     170    1.5   13.5      10     120        25      3    1.25  0.50
# 52     200    6.0   11.0      14     260        25      3    1.33  0.67
# 53     320    1.0   20.0       3      45       100      3    1.00  1.00
# 54       0    0.0   13.0       0      15         0      3    0.50  1.00
# 55       0    1.0   10.0       0      50         0      3    0.50  1.00
# 56     135    2.0   14.0       6     110        25      3    1.00  0.50
# 57       0    2.7   -1.0      -1     110         0      1    1.00  0.67
# 58     210    5.0   14.0      12     240        25      2    1.33  0.75
# 59     140    2.5   10.5       8     140        25      3    1.00  0.50
# 60       0    2.0   15.0       6     110        25      3    1.00  0.50
# 61     240    0.0   23.0       2      30        25      1    1.00  1.13
# 62     290    0.0   22.0       3      35        25      1    1.00  1.00
# 63       0    3.0   16.0       0      95         0      1    0.83  1.00
# 64       0    4.0   19.0       0     140         0      1    1.00  0.67
# 65       0    3.0   20.0       0     120         0      1    1.00  0.67
# 66      70    1.0    9.0      15      40        25      2    1.00  0.75
# 67     230    1.0   16.0       3      55        25      1    1.00  1.00
# 68      15    3.0   15.0       5      90        25      2    1.00  1.00
# 69     200    0.0   21.0       3      35       100      3    1.00  1.00
# 70     190    4.0   15.0      14     230       100      3    1.50  1.00
# 71     200    3.0   16.0       3     110       100      3    1.00  1.00
# 72     250    0.0   21.0       3      60        25      3    1.00  0.75
# 73     140    0.0   13.0      12      25        25      2    1.00  1.00
# 74     230    3.0   17.0       3     115        25      1    1.00  0.67
# 75     200    3.0   17.0       3     110        25      1    1.00  1.00
# 76     200    1.0   16.0       8      60        25      1    1.00  0.75
#
#        rating  shashank_ratings
# 0   68.402973                 2
# 1   33.983679                 3
# 2   59.425505                 2
# 3   93.704912                 4
# 4   34.384843                 3
# 5   29.509541                 5
# 6   33.174094                 1
# 7   37.038562                 2
# 8   49.120253                 4
# 9   53.313813                 3
# 10  18.042851                 1
# 11  50.764999                 1
# 12  19.823573                 1
# 13  40.400208                 4
# 14  22.736446                 3
# 15  41.445019                 1
# 16  45.863324                 5
# 17  35.782791                 5
# 18  22.396513                 1
# 19  40.448772                 4
# 20  64.533816                 3
# 21  46.895644                 5
# 22  36.176196                 5
# 23  44.330856                 4
# 24  32.207582                 1
# 25  31.435973                 1
# 26  58.345141                 2
# 27  40.917047                 2
# 28  41.015492                 3
# 29  28.025765                 4
# ..        ...               ...
# 47  40.105965                 3
# 48  29.924285                 1
# 49  40.692320                 3
# 50  59.642837                 3
# 51  30.450843                 3
# 52  37.840594                 1
# 53  41.503540                 5
# 54  60.756112                 4
# 55  63.005645                 5
# 56  49.511874                 3
# 57  50.828392                 1
# 58  39.259197                 3
# 59  39.703400                 2
# 60  55.333142                 5
# 61  41.998933                 1
# 62  40.560159                 3
# 63  68.235885                 2
# 64  74.472949                 1
# 65  72.801787                 5
# 66  31.230054                 3
# 67  53.131324                 5
# 68  59.363993                 3
# 69  38.839746                 2
# 70  28.592785                 4
# 71  46.658844                 2
# 72  39.106174                 2
# 73  27.753301                 4
# 74  49.787445                 2
# 75  51.592193                 3
# 76  36.187559                 1
#
# [77 rows x 17 columns]

# %%
## Test ##
assert len(cereal.columns) == 17

# %%
## Test ##
assert 'shashank_ratings' in cereal.columns

# %%
## Test ##
assert 'rating' in cereal.columns

# %%
## Test ##
assert type(cereal) == type(pd.DataFrame())

# %% [markdown]
# ## GroupBy

# %% [markdown]
# Shashank browses his favorite nutrition blog and sees several articles about the dangers of high sugar consumption.
# Unfortunately, he also has a big sweet tooth and is worried that he only likes eating cereals that are particularly sweet.
#
# Use `.groupby` to return a dataframe with a row for each rating and the average sugar content for the cereals that were given that rating.
# Make sure that your final dataframe has only one column, `mean_sugars`.
#
# Assign the dataframe to `mean_sugar_per_rating`.
#
# ```
# BEGIN QUESTION
# name: q6
# ```

# %%
mean_sugar_per_rating = cereal[['shashank_ratings', 'sugars']].groupby('shashank_ratings').mean() # SOLUTION
mean_sugar_per_rating = mean_sugar_per_rating.rename(columns={'sugars' : 'mean_sugars'}) # SOLUTION
mean_sugar_per_rating
# Out:
#                   mean_sugars
# shashank_ratings
# 1                    7.000000
# 2                    6.600000
# 3                    7.411765
# 4                    6.916667
# 5                    6.600000

# %%
## Test ##
assert len(mean_sugar_per_rating.columns) == 1

# %%
## Test ##
assert 'mean_sugars' in mean_sugar_per_rating.columns

# %%
## Test ##
assert np.isclose(7, mean_sugar_per_rating.iloc[0,0])

# %%
## Test ##
assert np.isclose(7.4117647, mean_sugar_per_rating.iloc[2,0])

# %%
## Test ##
assert type(mean_sugar_per_rating) == type(pd.DataFrame())

# %% [markdown]
# ## Pivot

# %% [markdown]
# After giving each cereal his personal rating, Shashank realizes that he wants to also get the cereal with the most
# protein as well. Shashank is trying to balance his personal taste rating with the amount of protein in each cereal.
# In the following cell, create a pivot table that compares `shashank_ratings` versus `protein` to visually aid us
# in balancing Shashank's personal taste and the amount of protein in each cereal. Assign this pivot table to `pivot_df`.
#
# ```
# BEGIN QUESTION
# name: q7
# ```

# %%
## SOLUTION ##

pivot_df = pd.pivot_table(cereal, values='name', index = 'protein', columns = 'shashank_ratings', aggfunc=list) # SOLUTION
pivot_df
# Out:
# shashank_ratings                                                  1  \
# protein
# 1                 [Cap'n'Crunch, Cinnamon Toast Crunch, Count Ch...
# 2                 [Apple Jacks, Corn Chex, Froot Loops, Just Rig...
# 3                   [Post Nat. Raisin Bran, Shredded Wheat 'n'Bran]
# 4                                                     [Life, Maypo]
# 5                                                  [Quaker Oatmeal]
# 6                                                        [Cheerios]
#
# shashank_ratings                                                  2  \
# protein
# 1                                      [Golden Grahams, Honey-comb]
# 2                      [Shredded Wheat, Total Corn Flakes, Triples]
# 3                 [Basic 4, Frosted Mini-Wheats, Fruit & Fibre D...
# 4                                             [100% Bran, All-Bran]
# 5                                                               NaN
# 6                                                               NaN
#
# shashank_ratings                                                  3  \
# protein
# 1                                                     [Cocoa Puffs]
# 2                 [Almond Delight, Multi-Grain Cheerios, Rice Kr...
# 3                 [100% Natural Bran, Bran Flakes, Cream of Whea...
# 4                 [Muesli Raisins; Peaches; & Pecans, Quaker Oat...
# 5                                                               NaN
# 6                                                               NaN
#
# shashank_ratings                                                  4  \
# protein
# 1                               [Fruity Pebbles, Puffed Rice, Trix]
# 2                                          [Bran Chex, Double Chex]
# 3                 [Clusters, Cracklin' Oat Bran, Grape Nuts Flak...
# 4                 [All-Bran with Extra Fiber, Muesli Raisins; Da...
# 5                                                               NaN
# 6                                                               NaN
#
# shashank_ratings                                                  5
# protein
# 1                                     [Corn Pops, Honey Graham Ohs]
# 2                 [Apple Cinnamon Cheerios, Corn Flakes, Crispix...
# 3                 [Grape-Nuts, Just Right Fruit & Nut, Product 1...
# 4                                                               NaN
# 5                                                               NaN
# 6                                                       [Special K]

# %%
## Test ##
assert "Cap'n'Crunch" in pivot_df.iloc[0,0]

# %%
## Test ##
assert 'Golden Grahams' in pivot_df.iloc[0,1]

# %%
## Test ##
assert 'Life' in pivot_df.iloc[3, 0]

# %%
## Test ##
assert 'Special K' in pivot_df.iloc[5,4]

# %%
## Test ##
assert type(pivot_df) == type(pd.DataFrame())
